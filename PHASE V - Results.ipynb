# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

no_SMOTE = pd.read_csv('data/final_predictions_noSMOTE.csv')
yes_SMOTE = pd.read_csv('final_predictions_last.csv')
tweets = pd.read_excel('data/final_tweets.xlsx')

no_SMOTE = no_SMOTE.drop(['Unnamed: 0'], axis = 1)
yes_SMOTE = yes_SMOTE.drop(['Unnamed: 0'], axis = 1)
tweets = tweets.drop(['Unnamed: 0'], axis = 1)

# %%
def find_percent(col, name):
    count = len(pd.Series(col)[col == 'bot'])
    length = len(pd.Series(col)[col == 'bot']) + len(pd.Series(col)[col == 'human'])
    return count / length

# %%
for (first_name, first_col), (fifth_name, fifth_col) in zip(yes_SMOTE.iteritems(), no_SMOTE.iteritems()):
    print('With SMOTE applied to dataset', first_name + ":", find_percent(first_col, first_name))
    print('  No SMOTE applied to dataset', fifth_name + ":", find_percent(fifth_col, fifth_name))
# Out:
# With SMOTE applied to dataset One Congress, Boston: 0.23880597014925373
#   No SMOTE applied to dataset One Congress, Boston: 0.14427860696517414
# With SMOTE applied to dataset Transbay: 0.1913329464112981
#   No SMOTE applied to dataset Transbay: 0.13051044083526683
# With SMOTE applied to dataset SoFi Stadium: 0.34023285899094435
#   No SMOTE applied to dataset SoFi Stadium: 0.24129032258064517
# With SMOTE applied to dataset Treasure Island: 0.2962264150943396
#   No SMOTE applied to dataset Treasure Island: 0.18975808985234055
# With SMOTE applied to dataset Port Covington: 0.22075557578516158
#   No SMOTE applied to dataset Port Covington: 0.15475648611743287
# With SMOTE applied to dataset Parkmerced: 0.272108843537415
#   No SMOTE applied to dataset Parkmerced: 0.15419501133786848
# With SMOTE applied to dataset Belmont Park: 0.23924268502581755
#   No SMOTE applied to dataset Belmont Park: 0.14556416881998277
# With SMOTE applied to dataset Lincoln Yards: 0.20812437311935808
#   No SMOTE applied to dataset Lincoln Yards: 0.1347695390781563
# With SMOTE applied to dataset Capitol Crossing: 0.22361359570661896
#   No SMOTE applied to dataset Capitol Crossing: 0.13774597495527727
# With SMOTE applied to dataset Candlestick: 0.31868662481892807
#   No SMOTE applied to dataset Candlestick: 0.22865412445730826
# With SMOTE applied to dataset Allston Yards: 0.17518248175182483
#   No SMOTE applied to dataset Allston Yards: 0.1386861313868613
# With SMOTE applied to dataset Giambrocco: 0.4
#   No SMOTE applied to dataset Giambrocco: 0.4
# With SMOTE applied to dataset 2110 Bay: 0.29411764705882354
#   No SMOTE applied to dataset 2110 Bay: 0.23529411764705882
# With SMOTE applied to dataset Southern Post: 0.4
#   No SMOTE applied to dataset Southern Post: 0.35
# With SMOTE applied to dataset Commerce Point: 0.5555555555555556
#   No SMOTE applied to dataset Commerce Point: 0.24074074074074073
# With SMOTE applied to dataset Burnham Place: 0.2
#   No SMOTE applied to dataset Burnham Place: 0.1111111111111111
# With SMOTE applied to dataset Reeves Creek: 0.6666666666666666
#   No SMOTE applied to dataset Reeves Creek: 0.5
# With SMOTE applied to dataset Perimeter Center East: 0.14285714285714285
#   No SMOTE applied to dataset Perimeter Center East: 0.12244897959183673
# With SMOTE applied to dataset Millenium Place: 0.2
#   No SMOTE applied to dataset Millenium Place: 0.1
# With SMOTE applied to dataset Centennial Yards: 0.22266560255387072
#   No SMOTE applied to dataset Centennial Yards: 0.15544871794871795
# With SMOTE applied to dataset Miami World Center: 0.3829113924050633
#   No SMOTE applied to dataset Miami World Center: 0.2879746835443038
# With SMOTE applied to dataset Pacific Park: 0.3640592694693315
#   No SMOTE applied to dataset Pacific Park: 0.2771851342050929
# With SMOTE applied to dataset Riverside South: 0.33125
#   No SMOTE applied to dataset Riverside South: 0.2336448598130841
# With SMOTE applied to dataset Jodeco 158: 0.42857142857142855
#   No SMOTE applied to dataset Jodeco 158: 0.2857142857142857
# With SMOTE applied to dataset Washington Terrace: 0.1375
#   No SMOTE applied to dataset Washington Terrace: 0.125
# With SMOTE applied to dataset Hudson Yards: 0.2970058275838971
#   No SMOTE applied to dataset Hudson Yards: 0.2141710156563629
# With SMOTE applied to dataset Bankside Bronx: 0.1
#   No SMOTE applied to dataset Bankside Bronx: 0.1
# With SMOTE applied to dataset "Midtown West" Detroit: 0.2222222222222222
#   No SMOTE applied to dataset "Midtown West" Detroit: 0.2222222222222222
# With SMOTE applied to dataset "La Central" Bronx: 0.4574898785425101
#   No SMOTE applied to dataset "La Central" Bronx: 0.3805668016194332

# %%
results = []
new_res = pd.DataFrame()
for name, col in yes_SMOTE.iteritems():
    if len(pd.Series(col)[col == 'bot']) + len(pd.Series(col)[col == 'human']) > 20:
        new_res[name] = col
for name, column in new_res.iteritems():
    results.append(find_percent(column, name))

plt.barh(y = new_res.columns, width = results, linewidth = 50)
plt.rcParams.update({'font.size': 10})
plt.xlim(0, .6)
plt.title('Bot Percentages for Developments with 20+ Tweets (Predictions from Model w/ SMOTE)')
plt.show()

# %%
results = []
new_res = pd.DataFrame()
for name, col in no_SMOTE.iteritems():
    if len(pd.Series(col)[col == 'bot']) + len(pd.Series(col)[col == 'human']) > 20:
        new_res[name] = col
for name, column in new_res.iteritems():
    results.append(find_percent(column, name))

plt.barh(y = new_res.columns, width = results, linewidth = 50)
plt.rcParams.update({'font.size': 10})
plt.xlim(0, .6)
plt.title('Bot Percentages for Developments with 20+ Tweets (Predictions from Model with no SMOTE)')
plt.show()

# %%
results = []
new_res = pd.DataFrame()
for name, col in yes_SMOTE.iteritems():
    if len(pd.Series(col)[col == 'bot']) + len(pd.Series(col)[col == 'human']) > 20:
        new_res[name] = col
for name, column in new_res.iteritems():
    results.append(len(pd.Series(column)[column == 'bot']))

plt.barh(y = new_res.columns, width = results, linewidth = 50)
plt.rcParams.update({'font.size': 10})
plt.title('Absolute # of Bots for Developments with 20+ Tweets (Predictions from Model w/ SMOTE)')
plt.show()

# %%
results = []
new_res = pd.DataFrame()
for name, col in no_SMOTE.iteritems():
    if len(pd.Series(col)[col == 'bot']) + len(pd.Series(col)[col == 'human']) > 20:
        new_res[name] = col
for name, column in new_res.iteritems():
    results.append(len(pd.Series(column)[column == 'bot']))

plt.barh(y = new_res.columns, width = results, linewidth = 50)
plt.rcParams.update({'font.size': 10})
plt.xlim(0, 4500)
plt.title('Absolute # of Bots for Developments with 20+ Tweets (Predictions from Model with no SMOTE)')
plt.show()
